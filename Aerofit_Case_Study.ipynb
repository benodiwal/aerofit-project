# %% [markdown]
# <a href="https://colab.research.google.com/github/benodiwal/aerofit-project/blob/main/Aerofit_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About this dataset
# **About Aerofit**: Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.

# %% [markdown]
# ## Buisness Problem
#
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.

# %% [markdown]
# ## Product Portfolio:
#
# - The KP281 is an entry-level treadmill that sells for \$1,500.
# - The KP481 is for mid-level runners that sell for \$1,750.
# - The KP781 treadmill is having advanced features that sell for $2,500
# Metric
#
# We will use count of users, probabilities, conditional probabilities to evaluate the users and create a customer profile for each product

# %% [markdown]
# Dataset link [here](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749)
#
# Preliminary info about the features of the Dataset:
#
# - Product Purchased: KP281, KP481, or KP781
# - Age: In years
# - Gender: Male/Female
# - Education: In years
# - MaritalStatus: Single or partnered
# - Usage: The average number of times the customer plans to use the treadmill each week.
# - Income: Annual income (in $)
# - Fitness: Self-rated fitness on a 1-to-5 scale, where 1 is the poor shape and 5 is the excellent
# - Miles: The average number of miles the customer expects to walk/run each week

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749
# Out:
# --2024-03-20 17:29:12--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.172.139.46, 18.172.139.94, 18.172.139.210, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.172.139.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7279 (7.1K) [text/plain]
# Saving to: ‘aerofit_treadmill.csv?1639992749.2’
#
# aerofit_treadmill.c 100%[===================>]   7.11K  --.-KB/s    in 0s
#
# 2024-03-20 17:29:12 (1.43 GB/s) - ‘aerofit_treadmill.csv?1639992749.2’ saved [7279/7279]

# %%
data = pd.read_csv('aerofit_treadmill.csv?1639992749')

# %% [markdown]
# ## Data Exploration

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# We will try to find some relationship between different features to get some insights regarding the data.

# %%
data.shape
# Out:
# (180, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# Product, Gender, Marital Status are in string format and all other data are in the integer format

# %%
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# No null values in the dataset

# %%
data.sort_values(by='Income', ascending=True)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 1     KP281   19    Male         15        Single      2        3   31836
# 80    KP481   19    Male         14        Single      3        3   31836
# 3     KP281   19    Male         12        Single      3        3   32973
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 171   KP781   33  Female         18     Partnered      4        5   95866
# 169   KP781   30    Male         18     Partnered      5        5   99601
# 168   KP781   30    Male         18     Partnered      5        4  103336
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 174   KP781   38    Male         18     Partnered      5        5  104581
#
#      Miles
# 0      112
# 2       66
# 1       75
# 80      64
# 3       85
# ...

# %%
data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ### Some observations
# - Product Distribution: There are three different products, with "KP281" being the most frequent one, appearing 80 times in the dataset.
#
# - Age Distribution: The age of the customers ranges from 18 to 50 years old. The average age is approximately 28.79 years old, with a standard deviation of 6.94.
#
# - Gender: There are two genders represented in the data, with males being the majority (104 out of 180).
#
# - Education: Education level ranges from 12 to 21 years, with an average of 15.57 years.
#
# - Marital Status: Most customers are partnered (107 out of 180).
#
# - Usage: The usage of the product varies, with an average of 3.46 times per week and a standard deviation of 1.08.
#
# - Fitness Level: Customers' self-reported fitness level ranges from 1 to 5, with an average of 3.31 and a standard deviation of 0.96.
#
# - Income: Income ranges from $29,562 to $104,581, with an average income of $53,719 and a standard deviation of $16,506.
#
# - Miles: Customers report using the product for distances ranging from 21 to 360 miles. The average distance is approximately 103.19 miles, with a standard deviation of 51.86.

# %%
plt.figure(figsize=(10,10))
plt.suptitle('Boxplots for Outliers Check', fontsize = 24)


plt.subplot(2,2,1)
sns.boxplot(data, x="Product", y="Usage", color='skyblue')
plt.xlabel('Treadmill Models')
plt.ylabel('Usage (Avg # / Week)')
plt.title('Usage VS Product', fontsize = 16)

plt.subplot(2,2,2)
sns.boxplot(data, x="Product", y="Age", color='salmon')
plt.xlabel('Treadmill Models')
plt.ylabel('Age (years)')
plt.title('Age VS Product', fontsize = 16)

plt.subplot(2,2,3)
sns.boxplot(data, x="Product", y="Miles", color='lightgreen')
plt.xlabel('Treadmill Models')
plt.ylabel('Avg Miles / Week')
plt.title('Miles VS Product', fontsize = 16)

plt.subplot(2,2,4)
sns.boxplot(data, x="Product", y="Income", color='coral')
plt.xlabel('Treadmill Models')
plt.ylabel('Income (Annual income in $)')
plt.title('Income VS Product', fontsize = 16)



plt.tight_layout(pad=2.0)
plt.show()

# %% [markdown]
# No need to clip the data as we are not making or training any model so we will work on the whole data.

# %% [markdown]
# ## Non-Graphical Analysis

# %%
p_count=data['Product'].value_counts()
p_count
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
vals = data['Product'].value_counts()
labels = vals.index
plt.title('Distribution of Treadmills Models', fontsize = 22)
plt.pie(vals, labels=labels, explode = [0.02,0.02,0.02], autopct='%1.0f%%',
        startangle=90, counterclock=False, colors=['orange', 'blue', 'yellow'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2305a3250>,
# ...
#  [Text(1.1029846853969052, 0.1944859475126421, 'KP281'),
#   Text(-0.7199221674761052, -0.8579697388466023, 'KP481'),
#   Text(-0.7199220469827118, 0.8579698399525605, 'KP781')],
#  [Text(0.6105808079875725, 0.10766186380164114, '44%'),
#   Text(-0.3985283427099867, -0.47494753400436907, '33%'),
#   Text(-0.3985282760082869, 0.4749475899737388, '22%')])

# %% [markdown]
# From this we know that the selling order of the products is KP281 > KP481 > KP781

# %%
data['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
data_p = data['Gender'].value_counts()
labels = data_p.index
plt.title('Distribution of Gender', fontsize = 20)
plt.pie(data_p, labels=labels, explode = [0.01,0.01], autopct='%1.0f%%',
        startangle=90, counterclock=False, colors=['lightcoral', 'grey'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2305fe4d0>,
# ...
#  [Text(1.0770282349354128, -0.268533389268279, 'Male'),
#   Text(-1.0770282097934978, 0.2685334901069388, 'Female')],
#  [Text(0.5918803813609025, -0.14757240311139658, '58%'),
#   Text(-0.5918803675441744, 0.1475724585272366, '42%')])

# %% [markdown]
# Male customers have 58% share in data while Female Customers have only 42% share.

# %%
data['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
data_p = data['MaritalStatus'].value_counts()
labels = data_p.index
plt.title('Distribution of Marital Status', fontsize = 20)
plt.pie(data_p, labels=labels, explode = [0.01,0.01], autopct='%1.0f%%',
        startangle=90, counterclock=False, colors=['cyan', 'magenta'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2304592a0>,
# ...
#  [Text(1.0614982696658786, -0.3245326231619039, 'Partnered'),
#   Text(-1.0614982696658786, 0.32453262316190373, 'Single')],
#  [Text(0.5833458959425096, -0.178346756872758, '59%'),
#   Text(-0.5833458959425096, 0.1783467568727579, '41%')])

# %% [markdown]
# 59% Customers are married while 41% customers are single.

# %% [markdown]
# ## Graphical Analysis

# %%
plt.figure(figsize=(10,15))
plt.suptitle('Univariate Analysis', fontsize=20)

# Treadmill Model Counts
plt.subplot(4,3,1)
sns.countplot(data, x= 'Product', color='lavender')

# Age Count
plt.subplot(4,3,2)
sns.histplot(data, x= 'Age', color='red')

# Gender Count
plt.subplot(4,3,3)
sns.countplot(data, x= 'Gender', color='lightgreen')

# Education Count
plt.subplot(4,3,4)
sns.countplot(data, x= 'Education', color='blue')

# Marital Status Count
plt.subplot(4,3,5)
sns.countplot(data, x= 'MaritalStatus', color='cyan')

# Usage Count
plt.subplot(4,3,6)
sns.countplot(data, x= 'Usage', color='grey')

# Fitness Count
plt.subplot(4,3,7)
sns.countplot(data, x= 'Fitness', color='lightcoral')

# Income Count
plt.subplot(4,3,8)
sns.histplot(data, x= 'Income', color='pink')

# Miles Count
plt.subplot(4,3,9)
sns.histplot(data, x= 'Miles', color='gold')


plt.tight_layout(pad=2.0)

# %% [markdown]
# Some Observations
#
# - The majority of customers have attained education levels ranging from 14 to 16 years, indicating a relatively educated clientele.
# - Income distribution among customers is centered around the $45,000 to $60,000 range, suggesting that a considerable proportion of customers belong to this income bracket.
# - The company's customer base primarily comprises individuals aged between 20 to 30 years, indicating a significant presence of younger consumers.
# - There is a notable gender imbalance among customers, with a higher representation of males compared to females.

# %% [markdown]
# Not much insights could be gathered from this data, we can try to do it product by product now

# %% [markdown]
# We see a general decline in females buying higher end product.

# %%
plt.figure(figsize=(10,15))
plt.suptitle('Some analysis', fontsize = 24)

plt.subplot(3,2,1)
sns.lineplot(data, x='Usage', y='Fitness', color='red')
plt.xlabel('Usage')
plt.ylabel('Fitness')
plt.title('Education v/s Usage')

plt.subplot(3,2,2)
sns.barplot(data, x='MaritalStatus', y='Usage', color='teal')
plt.xlabel('Martial Status')
plt.ylabel('Usage')
plt.title('MartialStatus v/s Usage')

plt.subplot(3,2,3)
sns.barplot(data, x='Income', y='Usage', color='indigo')
plt.xlabel('Income')
plt.ylabel('Usage')
plt.title('Income v/s Usage')

custom_palette = ['skyblue', 'lightgreen']

plt.subplot(3, 2, 4)
sns.countplot(data, x='Product', hue='Gender', palette=custom_palette)
plt.title('Product Purchased VS Gender', fontsize= 18, color= 'green')
plt.ylabel('No. of Treadmills Purchased', fontsize= 15, color= 'indigo')
plt.xlabel('Treadmills Purchased', fontsize= 15, color= 'skyblue')

plt.subplot(3, 2, 5)
sns.barplot(data, x='Gender', y='Usage', color='brown')
plt.xlabel('Gender')
plt.ylabel('Usage')


plt.tight_layout(pad=2.0)
plt.show()

# %% [markdown]
# - We notice a nearly linear relationship between education level and product usage, suggesting that customers with higher levels of education tend to use the product more frequently.
# - Our analysis did not reveal substantial insights regarding the relationship between income and product usage, suggesting that income alone may not be a reliable predictor of usage behavior.
# - There appears to be minimal correlation between marital status and product usage, indicating that whether a customer is partnered or not does not significantly impact their usage of the product.

# %%
fig,ax=plt.subplots(3,2,figsize=(10,11))
fig.subplots_adjust(wspace=.5,hspace=.5)
fig.suptitle('Bivariate Analysis',y=.95,fontsize=16,color='red')

sns.countplot(data, x='Product', hue='Gender', ax=ax[0, 0], palette='Set1')
sns.countplot(data, x='Product', hue='MaritalStatus', ax=ax[0, 1], palette='Set2')
sns.countplot(data, x='Usage', hue='Product', ax=ax[1, 0], palette='Set3')
sns.countplot(data, x='Fitness', hue='Product', ax=ax[1, 1], palette='Pastel1')
sns.countplot(data, x='Education', hue='Product', ax=ax[2, 0], palette='Pastel2')
sns.countplot(data, x='Fitness', hue='Gender', ax=ax[2, 1], palette='Dark2')

ax[0,0].set_title('Product vs Gender')
ax[0,1].set_title('Product vs MaritalStatus')
ax[1,0].set_title('Usage vs Product')
ax[1,1].set_title('Fitness vs Product')
ax[2,0].set_title('Education vs Product')
ax[2,1].set_title('Fitness vs Gender')

plt.show()

# %% [markdown]
# Some observations
# - People whose usage is more than 3 days a week prefer machine KP781.
# - People with more than 16 years of education prefer to use KP781.
# - People with 16 years of education prefer to buy KP281.

# %% [markdown]
# # Probability

# %%
p_count=data['Product'].value_counts(normalize=True)
p_count
# Out:
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: Product, dtype: float64

# %% [markdown]
# - Probability that people will buy KP281 is 44%.
# - Probability that people will buy KP481 is 33%.
# - Probability that people will buy KP781 is 22%.

# %%
filtered_data = data[['Product','Gender']]
pd.crosstab(filtered_data['Product'], filtered_data['Gender'], margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %% [markdown]
# - The probability of a male buying KP281 is 38.4%.
# - The probability of a male buying KP481 is 29.8%.
# - The probability of a male buying KP781 is 31.7%.

# %%
print("Probability (Product | Partnered)")
print(data[data["MaritalStatus"] == "Partnered"]["Product"].value_counts(normalize=True))

print("\nProbability (Product | Single)")
data[data["MaritalStatus"] == "Single"]["Product"].value_counts(normalize=True)
# Out:
# Probability (Product | Partnered)
# KP281    0.448598
# KP481    0.336449
# KP781    0.214953
# Name: Product, dtype: float64
#
# Probability (Product | Single)
# KP281    0.438356
# KP481    0.328767
# KP781    0.232877
# Name: Product, dtype: float64

# %% [markdown]
# We observe that
# - Single users have a higher probability of buying KP781 than partnered users.
# - Partnered users have a higher probability of buying KP481.

# %%
print("Probability (MaritalStatus | KP281)")
print(data[data["Product"] == "KP281"]["MaritalStatus"].value_counts(normalize=True))

print("\nProbability (MaritalStatus | KP481)")
print(data[data["Product"] == "KP481"]["MaritalStatus"].value_counts(normalize=True))

print("\nProbability (MaritalStatus | KP781)")
print(data[data["Product"] == "KP781"]["MaritalStatus"].value_counts(normalize=True))
# Out:
# Probability (MaritalStatus | KP281)
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
#
# Probability (MaritalStatus | KP481)
# Partnered    0.6
# Single       0.4
# Name: MaritalStatus, dtype: float64
#
# Probability (MaritalStatus | KP781)
# Partnered    0.575
# Single       0.425
# Name: MaritalStatus, dtype: float64

# %%
print("\nProbability (Product | Single & Male)")
data[(data["MaritalStatus"] == "Single") & (data["Gender"]=="Male")]["Product"].value_counts(normalize=True)
# Out:
# Probability (Product | Single & Male)
# KP281    0.441860
# KP781    0.325581
# KP481    0.232558
# Name: Product, dtype: float64

# %%
print(" \nProbability (Product | Single & Female)")
data[(data["MaritalStatus"] == "Single") & (data["Gender"]=="Female")]["Product"].value_counts(normalize=True)
# Out:
#
# Probability (Product | Single & Female)
# KP481    0.466667
# KP281    0.433333
# KP781    0.100000
# Name: Product, dtype: float64

# %%
print("\nProbability (Product | Partnered & Male)")
data[(data["MaritalStatus"] == "Partnered") & (data["Gender"]=="Male")]["Product"].value_counts(normalize=True)
# Out:
# Probability (Product | Partnered & Male)
# KP281    0.344262
# KP481    0.344262
# KP781    0.311475
# Name: Product, dtype: float64

# %%
print("\nProbability (Product | Partnered & Female)")
data[(data["MaritalStatus"] == "Partnered") & (data["Gender"]=="Female")]["Product"].value_counts(normalize=True)
# Out:
# Probability (Product | Partnered & Female)
# KP281    0.586957
# KP481    0.326087
# KP781    0.086957
# Name: Product, dtype: float64

# %% [markdown]
# ## Correlation among different factors

# %%
continuous_columns = ["Age", "Education", "Usage", "Fitness", "Income", "Miles"]
sns.heatmap(data=data[continuous_columns].corr(), annot=True, vmin=-1, vmax=1, cmap='coolwarm')
plt.title("Heatmap of the Correlation of the dataset")
plt.show()

# %% [markdown]
# # Observations
#
# - The most sold treadmill model is 'KP281', while the least sold treadmill is 'KP781'.
# - The majority of customers fall within the age group of 20 to 30 years.
# - The company's customer base comprises more males than females.
# - Most customers have completed 14-16 years of education.
# - The majority of customers have incomes ranging from $45,000 to $60,000.
# - There are more partnered customers than single customers.
# - Most customers use the treadmill for 3 days a week.
# - The majority of customers rate their fitness level as 3, with fewer rating it as 1.
# - On average, customers run 94 miles per week on treadmills.

# %% [markdown]
# # Recomendations
#
# ### For **'KP481'**
# - Both male and female customers are almost equally likely to buy 'KP481', so the company should target both demographics.
# - Focus marketing efforts more towards customers with 14-16 years of education for 'KP481'.
# - Target more partnered customers than single customers for 'KP481'.
# - Target customers with a usage frequency of 3 days/week for 'KP481'.
#
# ### For **'KP281'**
# - Both male and female customers are equally likely to buy the model, so the company should target both demographics.
# - Target customers with a usage frequency of 3 days/week for 'KP281'.
# - Focus marketing efforts more towards partnered customers than single customers for 'KP281'.
# - Target customers with 16 years of education for 'KP281'.
#
# ### For **'KP781'**
# - Male customers are more likely to buy this product, so the company should tailor marketing strategies accordingly.
# - Target customers with 18 years of education for 'KP781'.
# - Target customers with a usage frequency of 4 days/week for 'KP781'.
# - Focus marketing efforts more towards partnered customers than single customers for 'KP781'.
